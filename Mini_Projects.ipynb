# %% [markdown]
# <a href="https://colab.research.google.com/github/madhureddy7716/TNS/blob/main/Mini_Projects.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Mini Project:**

# %% [markdown]
# # **Python Mini Project**

# %% [markdown]
# Simple Calculator

# %%
# Simple Calculator

num1 = float(input("Enter First Number: "))
num2 = float(input("Enter Second Number: "))

print("1. Addition")
print("2. Subtraction")
print("3. Multiplication")
print("4. Division")

choice = int(input("Enter Choice: "))

if choice == 1:
    print("Result =", num1 + num2)
elif choice == 2:
    print("Result =", num1 - num2)
elif choice == 3:
    print("Result =", num1 * num2)
elif choice == 4:
    print("Result =", num1 / num2)
else:
    print("Invalid Choice")
# Out:
# Enter First Number: 10
# Enter Second Number: 20
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# Enter Choice: 4
# Result = 0.5

# %% [markdown]
# To-Do List

# %%
# To-Do List

tasks = []

while True:
    print("\n1. Add Task")
    print("2. View Tasks")
    print("3. Exit")

    choice = int(input("Enter Choice: "))

    if choice == 1:
        task = input("Enter Task: ")
        tasks.append(task)
        print("Task Added Successfully")

    elif choice == 2:
        print("\nTasks:")
        for i in range(len(tasks)):
            print(i + 1, ".", tasks[i])

    elif choice == 3:
        print("Thank You")
        break

    else:
        print("Invalid Choice")
# Out:
# 1. Add Task
# 2. View Tasks
# 3. Exit
# Enter Choice: 1
# Enter Task: hello
# Task Added Successfully
#
# 1. Add Task
# 2. View Tasks
# 3. Exit
# Enter Choice: 2
#
# Tasks:
# 1 . hello
#
# 1. Add Task
# 2. View Tasks
# 3. Exit
# Enter Choice: 3
# Thank You

# %% [markdown]
# Create a Student Report Card Program using:
#
# 1.List → store student names
#
# 2.Set → store subjects
#
# 3.Tuple → store student information (name, age)
#
# 4.Dictionary → store subject-wise marks
#
# Requirements:
#
# 1.Ask the user to enter:
#
# *Student name
#
# *Age
#
# *Number of subjects
#
# 2.For each subject:
#
# *Enter subject name
#
# *Enter marks
#
# 3.Store:
#
# *Name in a list
#
# *Subjects in a set
#
# *Student info in a tuple
#
# *Marks in a dictionary
#
# 4.Print a report card showing:
#
# *Name
#
# *Age
#
# *Subjects
#
# *Marks
#
# *Total marks
#
# *Average marks   make with answer

# %%
# Student Report Card Program

# List to store student names
student_names = []

# Set to store subjects
subjects = set()

# Dictionary to store subject-wise marks
marks_dict = {}

# Input student details
name = input("Enter Student Name: ")
age = int(input("Enter Age: "))
num_subjects = int(input("Enter Number of Subjects: "))

# Store name in list
student_names.append(name)

# Store student info in tuple
student_info = (name, age)

# Input subjects and marks
for i in range(num_subjects):
    subject = input(f"Enter Subject {i+1} Name: ")
    marks = int(input(f"Enter Marks in {subject}: "))

    subjects.add(subject)
    marks_dict[subject] = marks

# Calculate total and average
total_marks = sum(marks_dict.values())
average_marks = total_marks / num_subjects

# Report Card
print("\n===== STUDENT REPORT CARD =====")
print("Name:", student_info[0])
print("Age:", student_info[1])
print("Subjects:", subjects)

print("\nSubject-wise Marks:")
for subject, marks in marks_dict.items():
    print(subject, ":", marks)

print("\nTotal Marks:", total_marks)
print("Average Marks:", average_marks)
# Out:
# Enter Student Name: madhu
# Enter Age: 13
# Enter Number of Subjects: 1
# Enter Subject 1 Name: python
# Enter Marks in python: 49
#
# ===== STUDENT REPORT CARD =====
# Name: madhu
# Age: 13
# Subjects: {'python'}
#
# Subject-wise Marks:
# python : 49
#
# Total Marks: 49
# Average Marks: 49.0

# %% [markdown]
# #**Numpy Mini Project**

# %% [markdown]
# 1. Student Result Analysis

# %%
import numpy as np

marks = np.array([78, 85, 92, 67, 88, 95, 73, 81])

print("Student Marks:", marks)
print("Highest Marks:", np.max(marks))
print("Lowest Marks:", np.min(marks))
print("Average Marks:", np.mean(marks))
print("Total Marks:", np.sum(marks))
print("Passed Students:", len(marks[marks >= 40]))
# Out:
# Student Marks: [78 85 92 67 88 95 73 81]
# Highest Marks: 95
# Lowest Marks: 67
# Average Marks: 82.375
# Total Marks: 659
# Passed Students: 8

# %% [markdown]
# 2. Employee Salary Analysis

# %%
import numpy as np

salary = np.array([25000, 30000, 28000, 45000, 50000, 35000])

print("Total Salary Expense:", np.sum(salary))
print("Average Salary:", np.mean(salary))
print("Highest Salary:", np.max(salary))
print("Lowest Salary:", np.min(salary))

updated_salary = salary + 5000
print("Updated Salary:", updated_salary)
# Out:
# Total Salary Expense: 213000
# Average Salary: 35500.0
# Highest Salary: 50000
# Lowest Salary: 25000
# Updated Salary: [30000 35000 33000 50000 55000 40000]

# %% [markdown]
# 3. Bank Transaction Analysis

# %%
import numpy as np

transactions = np.array([5000, -1200, 3000, -500, 2500, -1000])

print("Transactions:", transactions)

print("Net Balance Change:", np.sum(transactions))
print("Largest Credit:", np.max(transactions))
print("Largest Debit:", np.min(transactions))
# Out:
# Transactions: [ 5000 -1200  3000  -500  2500 -1000]
# Net Balance Change: 7800
# Largest Credit: 5000
# Largest Debit: -1200

# %% [markdown]
# 4. Sales Performance Analysis

# %%
import numpy as np

sales = np.array([1200, 1500, 1800, 2100, 2500, 1700, 2200])

print("Total Sales:", np.sum(sales))
print("Average Sales:", np.mean(sales))
print("Highest Sales:", np.max(sales))
print("Lowest Sales:", np.min(sales))

best_day = np.argmax(sales) + 1
print("Best Sales Day:", best_day)
# Out:
# Total Sales: 13000
# Average Sales: 1857.142857142857
# Highest Sales: 2500
# Lowest Sales: 1200
# Best Sales Day: 5

# %% [markdown]
# 5. OTP Generator

# %%
import numpy as np

otp = np.random.randint(100000, 999999)

print("Generated OTP:", otp)
# Out:
# Generated OTP: 520054

# %% [markdown]
# Weather Analysis

# %%
import numpy as np

temperature = np.array([32, 35, 31, 29, 36, 38, 34])

print("Temperatures:", temperature)

print("Average Temperature:", np.mean(temperature))
print("Highest Temperature:", np.max(temperature))
print("Lowest Temperature:", np.min(temperature))

hot_days = temperature[temperature > 35]
print("Hot Days:", hot_days)
# Out:
# Temperatures: [32 35 31 29 36 38 34]
# Average Temperature: 33.57142857142857
# Highest Temperature: 38
# Lowest Temperature: 29
# Hot Days: [36 38]

# %% [markdown]
# Write a Python program using NumPy to perform the following:
#
# Marks = 65, 78, 90, 55, 88
#
# Tasks:
#
# Create a NumPy array using these marks
#
# Find the average marks
#
# Find the highest marks
#
# Find the lowest marks

# %%
import numpy as np

# Create NumPy array
marks = np.array([65, 78, 90, 55, 88])

# Average marks
average = np.mean(marks)

# Highest marks
highest = np.max(marks)

# Lowest marks
lowest = np.min(marks)

print("Marks:", marks)
print("Average Marks:", average)
print("Highest Marks:", highest)
print("Lowest Marks:", lowest)
# Out:
# Marks: [65 78 90 55 88]
# Average Marks: 75.2
# Highest Marks: 90
# Lowest Marks: 55

# %% [markdown]
# # **Pandas Mini Project**

# %% [markdown]
# 1. Student Management System

# %%
import pandas as pd

data = {
    "Name": ["Madhu", "Ravi", "Priya", "Kiran", "Anu"],
    "Maths": [85, 90, 78, 88, 95],
    "Science": [80, 85, 75, 92, 90],
    "English": [70, 88, 82, 80, 95]
}

df = pd.DataFrame(data)

df["Total"] = df["Maths"] + df["Science"] + df["English"]
df["Average"] = df["Total"] / 3

df["Grade"] = df["Average"].apply(
    lambda x: "A" if x >= 90 else
              "B" if x >= 80 else
              "C"
)

print("Student Report")
print(df)

print("\nTopper")
print(df.loc[df["Total"].idxmax()])

print("\nLowest Scorer")
print(df.loc[df["Total"].idxmin()])
# Out:
# Student Report
#     Name  Maths  Science  English  Total    Average Grade
# 0  Madhu     85       80       70    235  78.333333     C
# 1   Ravi     90       85       88    263  87.666667     B
# 2  Priya     78       75       82    235  78.333333     C
# 3  Kiran     88       92       80    260  86.666667     B
# 4    Anu     95       90       95    280  93.333333     A
#
# Topper
# Name             Anu
# Maths             95
# Science           90
# English           95
# Total            280
# Average    93.333333
# Grade              A
# Name: 4, dtype: object
#
# Lowest Scorer
# Name           Madhu
# Maths             85
# Science           80
# English           70
# Total            235
# Average    78.333333
# Grade              C
# Name: 0, dtype: object

# %% [markdown]
# Employee Salary Management

# %%
import pandas as pd

data = {
    "Employee": ["A", "B", "C", "D", "E"],
    "Department": ["IT", "HR", "IT", "Sales", "HR"],
    "Salary": [50000, 40000, 60000, 45000, 55000]
}

df = pd.DataFrame(data)

df["Bonus"] = df["Salary"] * 0.10

print("Employee Data")
print(df)

print("\nAverage Salary")
print(df["Salary"].mean())

print("\nHighest Salary")
print(df.loc[df["Salary"].idxmax()])

print("\nDepartment Wise Salary")
print(df.groupby("Department")["Salary"].mean())
# Out:
# Employee Data
#   Employee Department  Salary   Bonus
# 0        A         IT   50000  5000.0
# 1        B         HR   40000  4000.0
# 2        C         IT   60000  6000.0
# 3        D      Sales   45000  4500.0
# 4        E         HR   55000  5500.0
#
# Average Salary
# 50000.0
#
# Highest Salary
# Employee           C
# Department        IT
# Salary         60000
# Bonus         6000.0
# Name: 2, dtype: object
#
# Department Wise Salary
# Department
# HR       47500.0
# IT       55000.0
# Sales    45000.0
# Name: Salary, dtype: float64

# %% [markdown]
# Cricket Statistics System

# %%
import pandas as pd

data = {
    "Player": ["Virat", "Rohit", "Gill", "Rahul", "Pant"],
    "Runs": [120, 80, 95, 45, 110],
    "Matches": [3, 3, 3, 3, 3]
}

df = pd.DataFrame(data)

df["Average"] = df["Runs"] / df["Matches"]

print("Cricket Statistics")
print(df)

print("\nHighest Run Scorer")
print(df.loc[df["Runs"].idxmax()])

print("\nLowest Run Scorer")
print(df.loc[df["Runs"].idxmin()])

print("\nPlayers with Runs > 100")
print(df[df["Runs"] > 100])

print("\nSorted by Runs")
print(df.sort_values(by="Runs", ascending=False))
# Out:
# Cricket Statistics
#   Player  Runs  Matches    Average
# 0  Virat   120        3  40.000000
# 1  Rohit    80        3  26.666667
# 2   Gill    95        3  31.666667
# 3  Rahul    45        3  15.000000
# 4   Pant   110        3  36.666667
#
# Highest Run Scorer
# Player     Virat
# Runs         120
# Matches        3
# Average     40.0
# Name: 0, dtype: object
#
# Lowest Run Scorer
# Player     Rahul
# Runs          45
# Matches        3
# Average     15.0
# Name: 3, dtype: object
#
# Players with Runs > 100
#   Player  Runs  Matches    Average
# 0  Virat   120        3  40.000000
# 4   Pant   110        3  36.666667
#
# Sorted by Runs
#   Player  Runs  Matches    Average
# 0  Virat   120        3  40.000000
# 4   Pant   110        3  36.666667
# 2   Gill    95        3  31.666667
# 1  Rohit    80        3  26.666667
# 3  Rahul    45        3  15.000000

# %% [markdown]
# Sales Analysis System

# %%
import pandas as pd

data = {
    "Product": ["Laptop", "Mobile", "Laptop", "TV", "Mobile"],
    "Quantity": [2, 5, 3, 1, 4],
    "Price": [50000, 20000, 50000, 30000, 20000]
}

df = pd.DataFrame(data)

df["Sales"] = df["Quantity"] * df["Price"]

print("Sales Report")
print(df)

print("\nTotal Revenue")
print(df["Sales"].sum())

print("\nProduct Wise Revenue")
print(df.groupby("Product")["Sales"].sum())

print("\nHighest Sale")
print(df.loc[df["Sales"].idxmax()])
# Out:
# Sales Report
#   Product  Quantity  Price   Sales
# 0  Laptop         2  50000  100000
# 1  Mobile         5  20000  100000
# 2  Laptop         3  50000  150000
# 3      TV         1  30000   30000
# 4  Mobile         4  20000   80000
#
# Total Revenue
# 460000
#
# Product Wise Revenue
# Product
# Laptop    250000
# Mobile    180000
# TV         30000
# Name: Sales, dtype: int64
#
# Highest Sale
# Product     Laptop
# Quantity         3
# Price        50000
# Sales       150000
# Name: 2, dtype: object

# %% [markdown]
# # **Task-3 :Hospital Patient Data Analysis**

# %%
# ==========================================
# Hospital Patient Data Analysis Project
# ==========================================

import pandas as pd
import numpy as np

# ------------------------------------------
# Dataset
# ------------------------------------------

data = {
    "Patient_ID": [101, 102, 103, 104, 105, 106, 106],
    "Name": ["Madhu", "Suresh", "Lakshmi", "Ramesh", "Kavya", "Vijay", "Vijay"],
    "Age": [45, 30, 55, np.nan, 40, 60, 60],
    "Disease": ["Diabetes", "Cancer", "Heart Disease", "Diabetes", "Cancer", "Asthma", "Asthma"],
    "Treatment_Cost": [50000, 120000, 80000, 60000, np.nan, 30000, 30000],
    "Days_Admitted": [10, 20, 15, 12, 18, 5, 5]
}

# Create DataFrame
df = pd.DataFrame(data)

# ------------------------------------------
# 1. Load and Inspect Dataset
# ------------------------------------------

print("=" * 60)
print("HOSPITAL PATIENT DATASET")
print("=" * 60)

print("\nDataset:")
print(df)

print("\nDataset Information:")
print(df.info())

print("\nFirst 5 Records:")
print(df.head())

print("\nMissing Values:")
print(df.isnull().sum())

# ------------------------------------------
# 2. Handle Missing Values
# ------------------------------------------

df["Age"] = df["Age"].fillna(df["Age"].mean())

df["Treatment_Cost"] = df["Treatment_Cost"].fillna(
    df["Treatment_Cost"].mean()
)

print("\n" + "=" * 60)
print("AFTER HANDLING MISSING VALUES")
print("=" * 60)

print(df)

# ------------------------------------------
# 3. Remove Duplicate Records
# ------------------------------------------

df = df.drop_duplicates()

print("\n" + "=" * 60)
print("AFTER REMOVING DUPLICATES")
print("=" * 60)

print(df)

# ------------------------------------------
# 4. Calculate Cost Per Day
# ------------------------------------------

df["Cost_Per_Day"] = (
    df["Treatment_Cost"] / df["Days_Admitted"]
)

print("\n" + "=" * 60)
print("COST PER DAY")
print("=" * 60)

print(df[["Name", "Cost_Per_Day"]])

# ------------------------------------------
# 5. Find Patients with Treatment Costs
#    Above Average
# ------------------------------------------

average_cost = df["Treatment_Cost"].mean()

above_average = df[
    df["Treatment_Cost"] > average_cost
]

print("\n" + "=" * 60)
print("PATIENTS WITH ABOVE AVERAGE COST")
print("=" * 60)

print(above_average[["Name", "Disease", "Treatment_Cost"]])

# ------------------------------------------
# 6. Sort by Treatment Cost
# ------------------------------------------

sorted_df = df.sort_values(
    by="Treatment_Cost",
    ascending=False
)

print("\n" + "=" * 60)
print("SORTED BY TREATMENT COST")
print("=" * 60)

print(sorted_df[["Name", "Treatment_Cost"]])

# ------------------------------------------
# 7. Disease-wise Average Treatment Cost
# ------------------------------------------

disease_average = df.groupby(
    "Disease"
)["Treatment_Cost"].mean()

print("\n" + "=" * 60)
print("DISEASE-WISE AVERAGE TREATMENT COST")
print("=" * 60)

print(disease_average)

# ------------------------------------------
# 8. Apply NumPy Statistical Functions
# ------------------------------------------

costs = df["Treatment_Cost"].to_numpy()

print("\n" + "=" * 60)
print("NUMPY STATISTICS")
print("=" * 60)

print("Mean Cost              :", np.mean(costs))
print("Median Cost            :", np.median(costs))
print("Maximum Cost           :", np.max(costs))
print("Minimum Cost           :", np.min(costs))
print("Standard Deviation     :", np.std(costs))

# ------------------------------------------
# 9. Find Most Expensive Treatment
# ------------------------------------------

most_expensive = df.loc[
    df["Treatment_Cost"].idxmax()
]

print("\n" + "=" * 60)
print("MOST EXPENSIVE TREATMENT")
print("=" * 60)

print("Patient Name     :", most_expensive["Name"])
print("Disease          :", most_expensive["Disease"])
print("Treatment Cost   :", most_expensive["Treatment_Cost"])
print("Days Admitted    :", most_expensive["Days_Admitted"])

# ------------------------------------------
# 10. Generate Hospital Report
# ------------------------------------------

print("\n" + "=" * 60)
print("HOSPITAL REPORT")
print("=" * 60)

print("Total Patients           :", len(df))
print("Average Age              :", round(df["Age"].mean(), 2))
print("Average Treatment Cost   :", round(df["Treatment_Cost"].mean(), 2))
print("Highest Treatment Cost   :", df["Treatment_Cost"].max())
print("Lowest Treatment Cost    :", df["Treatment_Cost"].min())

print("\nDisease-wise Average Cost:")
print(disease_average)

print("\nMost Expensive Treatment:")
print(most_expensive[["Name", "Disease", "Treatment_Cost"]])

print("\nReport Generated Successfully!")
print("=" * 60)
# Out:
# ...
# HOSPITAL PATIENT DATASET
# ...
#
# Dataset:
#    Patient_ID     Name   Age        Disease  Treatment_Cost  Days_Admitted
# 0         101    Madhu  45.0       Diabetes         50000.0             10
# 1         102   Suresh  30.0         Cancer        120000.0             20
# 2         103  Lakshmi  55.0  Heart Disease         80000.0             15
# 3         104   Ramesh   NaN       Diabetes         60000.0             12
# 4         105    Kavya  40.0         Cancer             NaN             18
# 5         106    Vijay  60.0         Asthma         30000.0              5
# 6         106    Vijay  60.0         Asthma         30000.0              5
#
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Patient_ID      7 non-null      int64
#  1   Name            7 non-null      object
# ...

# %% [markdown]
# #**Matplotlib Mini Project**

# %% [markdown]
# Problem : Student Marks Analysis
# Create a dataset containing marks of 10 students.
#
# students = ['A','B','C','D','E','F','G','H','I','J']
#
# marks = [78,85,92,67,88,95,72,81,90,76] Tasks
#
# Display student marks graphically.
# Find the highest scorer.
# Add appropriate title and axis labels.
# Display marks in descending order and plot again.

# %%
import matplotlib.pyplot as plt

# Dataset
students = ['A','B','C','D','E','F','G','H','I','J']
marks = [78,85,92,67,88,95,72,81,90,76]

# Find highest scorer
highest_marks = max(marks)
highest_student = students[marks.index(highest_marks)]

print("Highest Scorer :", highest_student)
print("Highest Marks  :", highest_marks)

# Graph 1: Original Marks
plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
plt.bar(students, marks, label="Marks")
plt.title("Student Marks Analysis")
plt.xlabel("Students")
plt.ylabel("Marks")
plt.legend()
plt.grid(True)

# Sort marks in descending order
combined = list(zip(students, marks))
combined.sort(key=lambda x: x[1], reverse=True)

sorted_students = [i[0] for i in combined]
sorted_marks = [i[1] for i in combined]

# Graph 2: Descending Order
plt.subplot(1,2,2)
plt.bar(sorted_students, sorted_marks, label="Descending Marks")
plt.title("Marks in Descending Order")
plt.xlabel("Students")
plt.ylabel("Marks")
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# Highest Scorer : F
# Highest Marks  : 95

# %% [markdown]
# Challenge:
#
# A hospital collected the ages of 500 patients. Visualize the age distribution and identify the most common age group.
# Try it with Kaggle dataset

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate sample ages for 500 patients
np.random.seed(42)
ages = np.random.randint(1, 90, 500)

# Histogram
plt.figure(figsize=(10,5))
plt.hist(ages, bins=10, edgecolor='black')

plt.title("Hospital Patient Age Distribution")
plt.xlabel("Age Groups")
plt.ylabel("Number of Patients")
plt.grid(True)

plt.show()

# Find most common age group
counts, bins = np.histogram(ages, bins=10)

max_index = np.argmax(counts)

print("Most Common Age Group:")
print(f"{int(bins[max_index])} - {int(bins[max_index+1])} years")
print("Number of Patients:", counts[max_index])
# Out:
# Most Common Age Group:
# 53 - 62 years
# Number of Patients: 64

# %% [markdown]
# Project 1: Student Performance Analysis

# %%
import matplotlib.pyplot as plt

students = ['A','B','C','D','E']
marks = [78,85,92,67,88]
study_hours = [2,4,6,1,5]

plt.figure(figsize=(12,8))

# Bar Chart
plt.subplot(2,2,1)
plt.bar(students, marks)
plt.title("Student Marks")
plt.xlabel("Students")
plt.ylabel("Marks")
plt.grid(True)

# Line Plot
plt.subplot(2,2,2)
plt.plot(students, marks, marker='o', color='green', label='Marks')
plt.title("Marks Trend")
plt.xlabel("Students")
plt.ylabel("Marks")
plt.legend()
plt.grid(True)

# Scatter Plot
plt.subplot(2,2,3)
plt.scatter(study_hours, marks)
plt.title("Study Hours vs Marks")
plt.xlabel("Hours")
plt.ylabel("Marks")
plt.grid(True)

# Pie Chart
plt.subplot(2,2,4)
plt.pie(marks, labels=students, autopct='%1.1f%%')
plt.title("Marks Contribution")

plt.tight_layout()
plt.show()

# %% [markdown]
# Project 2: Employee Salary Analysis

# %%
import matplotlib.pyplot as plt

employees = ['Emp1','Emp2','Emp3','Emp4','Emp5']
salary = [25000,30000,28000,40000,35000]

plt.figure(figsize=(12,8))

# Bar Chart
plt.subplot(2,2,1)
plt.bar(employees, salary)
plt.title("Employee Salary")
plt.xlabel("Employees")
plt.ylabel("Salary")

# Line Plot
plt.subplot(2,2,2)
plt.plot(employees, salary, marker='o', color='red', label='Salary')
plt.title("Salary Trend")
plt.legend()
plt.grid(True)

# Histogram
plt.subplot(2,2,3)
plt.hist(salary, bins=5)
plt.title("Salary Distribution")
plt.xlabel("Salary")
plt.ylabel("Frequency")

# Pie Chart
plt.subplot(2,2,4)
plt.pie(salary, labels=employees, autopct='%1.1f%%')
plt.title("Salary Share")

plt.tight_layout()
plt.show()

# %% [markdown]
# Movie Streaming Platform Analysis

# %%
import matplotlib.pyplot as plt

ott_platforms = [
    "Netflix",
    "Prime Video",
    "Disney+ Hotstar",
    "Sony LIV",
    "ZEE5",
    "Aha"
]

movie_counts = [120, 150, 90, 60, 70, 40]

plt.figure(figsize=(12,8))

# Bar Chart
plt.subplot(2,2,1)
plt.bar(ott_platforms, movie_counts)
plt.title("OTT Movie Count")

# Line Plot
plt.subplot(2,2,2)
plt.plot(ott_platforms, movie_counts, marker='o')
plt.title("OTT Trend")

# Pie Chart
plt.subplot(2,2,3)
plt.pie(movie_counts, labels=ott_platforms, autopct='%1.1f%%')
plt.title("OTT Share")

# Histogram
plt.subplot(2,2,4)
plt.hist(movie_counts, bins=5)
plt.title("Movie Distribution")

plt.tight_layout()
plt.show()

# Highest Platform
max_movies = max(movie_counts)
index = movie_counts.index(max_movies)

print("Platform with Most Movies:", ott_platforms[index])
print("Total Movies:", max_movies)
# Out:
# Platform with Most Movies: Prime Video
# Total Movies: 150

# %% [markdown]
# Mini Project: Cricket Score Analysis Using Matplotlib

# %%
import matplotlib.pyplot as plt

# Player Data
players = ["Virat", "Rohit", "Gill", "KL Rahul", "Hardik"]
runs = [85, 120, 65, 45, 90]

# Highest Scorer
highest_runs = max(runs)
highest_player = players[runs.index(highest_runs)]

print("Highest Scorer:", highest_player)
print("Runs:", highest_runs)

plt.figure(figsize=(12,8))

# 1. Bar Chart
plt.subplot(2,2,1)
plt.bar(players, runs)
plt.title("Player Runs")
plt.xlabel("Players")
plt.ylabel("Runs")
plt.grid(True)

# 2. Line Plot
plt.subplot(2,2,2)
plt.plot(players, runs, marker='o', label="Runs")
plt.title("Runs Trend")
plt.xlabel("Players")
plt.ylabel("Runs")
plt.legend()
plt.grid(True)

# 3. Pie Chart
plt.subplot(2,2,3)
plt.pie(runs, labels=players, autopct='%1.1f%%')
plt.title("Run Contribution")

# 4. Histogram
plt.subplot(2,2,4)
plt.hist(runs, bins=5)
plt.title("Run Distribution")
plt.xlabel("Runs")
plt.ylabel("Frequency")

plt.tight_layout()
plt.show()
# Out:
# Highest Scorer: Rohit
# Runs: 120
