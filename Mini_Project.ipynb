# %% [markdown]
# <a href="https://colab.research.google.com/github/madhureddy7716/TNS/blob/main/Mini_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Mini Project

# %% [markdown]
# Simple Calculator

# %%
# Simple Calculator

num1 = float(input("Enter First Number: "))
num2 = float(input("Enter Second Number: "))

print("1. Addition")
print("2. Subtraction")
print("3. Multiplication")
print("4. Division")

choice = int(input("Enter Choice: "))

if choice == 1:
    print("Result =", num1 + num2)
elif choice == 2:
    print("Result =", num1 - num2)
elif choice == 3:
    print("Result =", num1 * num2)
elif choice == 4:
    print("Result =", num1 / num2)
else:
    print("Invalid Choice")
# Out:
# Enter First Number: 10
# Enter Second Number: 20
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# Enter Choice: 4
# Result = 0.5

# %% [markdown]
# To-Do List

# %%
# To-Do List

tasks = []

while True:
    print("\n1. Add Task")
    print("2. View Tasks")
    print("3. Exit")

    choice = int(input("Enter Choice: "))

    if choice == 1:
        task = input("Enter Task: ")
        tasks.append(task)
        print("Task Added Successfully")

    elif choice == 2:
        print("\nTasks:")
        for i in range(len(tasks)):
            print(i + 1, ".", tasks[i])

    elif choice == 3:
        print("Thank You")
        break

    else:
        print("Invalid Choice")
# Out:
# 1. Add Task
# 2. View Tasks
# 3. Exit
# Enter Choice: 1
# Enter Task: hello
# Task Added Successfully
#
# 1. Add Task
# 2. View Tasks
# 3. Exit
# Enter Choice: 2
#
# Tasks:
# 1 . hello
#
# 1. Add Task
# 2. View Tasks
# 3. Exit
# Enter Choice: 3
# Thank You

# %% [markdown]
# Create a Student Report Card Program using:
#
# 1.List → store student names
#
# 2.Set → store subjects
#
# 3.Tuple → store student information (name, age)
#
# 4.Dictionary → store subject-wise marks
#
# Requirements:
#
# 1.Ask the user to enter:
#
# *Student name
#
# *Age
#
# *Number of subjects
#
# 2.For each subject:
#
# *Enter subject name
#
# *Enter marks
#
# 3.Store:
#
# *Name in a list
#
# *Subjects in a set
#
# *Student info in a tuple
#
# *Marks in a dictionary
#
# 4.Print a report card showing:
#
# *Name
#
# *Age
#
# *Subjects
#
# *Marks
#
# *Total marks
#
# *Average marks   make with answer

# %%
# Student Report Card Program

# List to store student names
student_names = []

# Set to store subjects
subjects = set()

# Dictionary to store subject-wise marks
marks_dict = {}

# Input student details
name = input("Enter Student Name: ")
age = int(input("Enter Age: "))
num_subjects = int(input("Enter Number of Subjects: "))

# Store name in list
student_names.append(name)

# Store student info in tuple
student_info = (name, age)

# Input subjects and marks
for i in range(num_subjects):
    subject = input(f"Enter Subject {i+1} Name: ")
    marks = int(input(f"Enter Marks in {subject}: "))

    subjects.add(subject)
    marks_dict[subject] = marks

# Calculate total and average
total_marks = sum(marks_dict.values())
average_marks = total_marks / num_subjects

# Report Card
print("\n===== STUDENT REPORT CARD =====")
print("Name:", student_info[0])
print("Age:", student_info[1])
print("Subjects:", subjects)

print("\nSubject-wise Marks:")
for subject, marks in marks_dict.items():
    print(subject, ":", marks)

print("\nTotal Marks:", total_marks)
print("Average Marks:", average_marks)
# Out:
# Enter Student Name: madhu
# Enter Age: 13
# Enter Number of Subjects: 1
# Enter Subject 1 Name: python
# Enter Marks in python: 49
#
# ===== STUDENT REPORT CARD =====
# Name: madhu
# Age: 13
# Subjects: {'python'}
#
# Subject-wise Marks:
# python : 49
#
# Total Marks: 49
# Average Marks: 49.0
